# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
data = pd.read_excel('/home/shakkib/Documents/assignment gfg.xlsx')

# %%
import langdetect as ld
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-a53d56a26a99> in <module>
# ----> 1 import langdetect as ld
#
# ModuleNotFoundError: No module named 'langdetect'

# %%
import pandas as pd
data = pd.read_excel('/home/shakkib/Documents/assignment gfg.xlsx')

# %%
pip install xlrd

# %%
import pandas as pd
data = pd.read_excel('/home/shakkib/Documents/assignment gfg.xlsx')

# %%
pip install openpyxl

# %%
import pandas as pd
data = pd.read_excel('/home/shakkib/Documents/assignment gfg.xlsx')

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0         NaN        NaN        NaN         NaN
# 1         NaN        NaN        NaN         NaN
# 2         NaN        NaN        NaN         NaN
# 3         NaN        NaN        NaN         NaN
# 4         NaN       text         id  created_at

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2005 entries, 0 to 2004
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  0 non-null      float64
#  2   Unnamed: 2  0 non-null      float64
#  3   Unnamed: 3  0 non-null      float64
#  4   Unnamed: 4  0 non-null      float64
#  5   Unnamed: 5  0 non-null      float64
#  6   Unnamed: 6  0 non-null      float64
#  7   Unnamed: 7  2001 non-null   object
#  8   Unnamed: 8  2001 non-null   object
#  9   Unnamed: 9  2001 non-null   object
# dtypes: float64(7), object(3)
# memory usage: 156.8+ KB

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-3d8483998d6f> in <module>
# ----> 1 data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
data.tail(10)
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 1995         NaN         NaN         NaN         NaN         NaN         NaN
# 1996         NaN         NaN         NaN         NaN         NaN         NaN
# 1997         NaN         NaN         NaN         NaN         NaN         NaN
# 1998         NaN         NaN         NaN         NaN         NaN         NaN
# 1999         NaN         NaN         NaN         NaN         NaN         NaN
# 2000         NaN         NaN         NaN         NaN         NaN         NaN
# 2001         NaN         NaN         NaN         NaN         NaN         NaN
# 2002         NaN         NaN         NaN         NaN         NaN         NaN
# 2003         NaN         NaN         NaN         NaN         NaN         NaN
# 2004         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 6                                         Unnamed: 7  \
# ...

# %%
data1=data.drop(['Unnamed: 0','Unnamed: 1','Unnamed: 2','Unnamed: 3','Unnamed: 4', 'Unnamed: 5' ,'Unnamed: 6','Unnamed: 8'],axis=1)

# %%
data1.head(10)
# Out:
#                                           Unnamed: 7                Unnamed: 9
# 0                                                NaN                       NaN
# 1                                                NaN                       NaN
# 2                                                NaN                       NaN
# 3                                                NaN                       NaN
# 4                                               text                created_at
# 5  #Cientificos #Delincuentes https://t.co/qMuDl8...  2020-03-22T16:33:33.000Z
# 6  Packed UK concerts amid rising Covid-19 cases ...  2020-03-22T11:35:12.000Z
# 7  #DiputadasQuerétaro   QUERÉTARO REFERENTE A NI...  2020-03-22T15:10:57.000Z
# 8  QUE PUTAS YA SON TANTOS, PARCEEEE??? O SEA EN ...  2020-03-22T05:21:12.000Z
# 9  en misiones no hay casos porque acá tenemos al...  2020-03-22T15:42:33.000Z

# %%
data1.head(10)

# %%
data2 = data1.dropna()

# %%
data2.head(10)
# Out:
#                                            Unnamed: 7  \
# 4                                                text
# 5   #Cientificos #Delincuentes https://t.co/qMuDl8...
# 6   Packed UK concerts amid rising Covid-19 cases ...
# 7   #DiputadasQuerétaro   QUERÉTARO REFERENTE A NI...
# 8   QUE PUTAS YA SON TANTOS, PARCEEEE??? O SEA EN ...
# 9   en misiones no hay casos porque acá tenemos al...
# 10  Última hora: Pedro Sánchez avança als presiden...
# 11  @derek_adesso Hover over any location in the w...
# 12                            https://t.co/AYPd7erCiB
# 13  段々と外堀が、埋まってきましたね！ こんな状況で通常開催にこだわる日本政府は愚か💢\n\n【...
#
#                   Unnamed: 9
# 4                 created_at
# 5   2020-03-22T16:33:33.000Z
# 6   2020-03-22T11:35:12.000Z
# 7   2020-03-22T15:10:57.000Z
# 8   2020-03-22T05:21:12.000Z
# 9   2020-03-22T15:42:33.000Z
# 10  2020-03-22T10:07:30.000Z
# 11  2020-03-22T04:08:28.000Z
# 12  2020-03-22T04:45:00.000Z
# 13  2020-03-22T09:32:08.000Z

# %%
pip install langid

# %%
data2.columns = data2.iloc[0]

data2 = data2.iloc[1:].reset_index(drop=True)

# %%
data2.head(10)
# Out:
# 4                                               text                created_at
# 0  #Cientificos #Delincuentes https://t.co/qMuDl8...  2020-03-22T16:33:33.000Z
# 1  Packed UK concerts amid rising Covid-19 cases ...  2020-03-22T11:35:12.000Z
# 2  #DiputadasQuerétaro   QUERÉTARO REFERENTE A NI...  2020-03-22T15:10:57.000Z
# 3  QUE PUTAS YA SON TANTOS, PARCEEEE??? O SEA EN ...  2020-03-22T05:21:12.000Z
# 4  en misiones no hay casos porque acá tenemos al...  2020-03-22T15:42:33.000Z
# 5  Última hora: Pedro Sánchez avança als presiden...  2020-03-22T10:07:30.000Z
# 6  @derek_adesso Hover over any location in the w...  2020-03-22T04:08:28.000Z
# 7                            https://t.co/AYPd7erCiB  2020-03-22T04:45:00.000Z
# 8  段々と外堀が、埋まってきましたね！ こんな状況で通常開催にこだわる日本政府は愚か💢\n\n【...  2020-03-22T09:32:08.000Z
# 9      @realDonaldTrump Asshole it's called covid-19  2020-03-22T04:33:54.000Z

# %%
data3=data2[data2.text.map(lambda x: x.isascii())]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-10ccacc750b1> in <module>
# ----> 1 data3=data2[data2.text.map(lambda x: x.isascii())]
#
# /home/shakkib/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3907         dtype: object
#    3908         """
# -> 3909         new_values = super()._map_values(arg, na_action=na_action)
#    3910         return self._constructor(new_values, index=self.index).__finalize__(
#    3911             self, method="map"
#
# /home/shakkib/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     935
#     936         # mapper is a function
# --> 937         new_values = map_f(values, mapper)
#     938
#     939         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...
